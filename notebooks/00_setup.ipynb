# %% [markdown]
# <a href="https://colab.research.google.com/github/WeegorMartins/customer-decisioning-lab/blob/main/notebooks/00_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 00 — Preparação do ambiente
#
# Objetivo: instalar, importar e testar as ferramentas gratuitas.
#
# Regra: esta etapa não treina modelos e não produz resultado de negócio.
# ```

# %%
# !pip -q install -U lightgbm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 25.0 MB/s eta 0:00:00

# %%
import sys
import random
import platform

import numpy as np
import pandas as pd
import sklearn
import lightgbm

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

print("Python:", sys.version.split()[0])
print("Sistema:", platform.system())
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("scikit-learn:", sklearn.__version__)
print("LightGBM:", lightgbm.__version__)
print("SEED:", SEED)
print("AMBIENTE PRONTO")
# Out:
# Python: 3.12.13
# Sistema: Linux
# NumPy: 2.0.2
# Pandas: 2.2.2
# scikit-learn: 1.6.1
# LightGBM: 4.7.0
# SEED: 42
# AMBIENTE PRONTO

# %%
teste = pd.DataFrame({
    "cliente": [1, 2, 3],
    "valor": [10.0, 20.0, 30.0]
})

display(teste)
print("Soma:", teste["valor"].sum())
# Out:
#    cliente  valor
# 0        1   10.0
# 1        2   20.0
# 2        3   30.0
# Soma: 60.0
